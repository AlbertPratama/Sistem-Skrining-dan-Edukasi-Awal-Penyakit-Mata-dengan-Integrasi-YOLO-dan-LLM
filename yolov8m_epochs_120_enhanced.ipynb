# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
from roboflow import Roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="kRTto3E07NvJf8T6oo1y")
project = rf.workspace("detectoreyesdisease").project("eyes_detect-van31")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to eyes_detect-4 in yolov8:: 100%|██████████| 1551/1551 [00:00<00:00, 4729.31it/s]

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolov8m.pt" epochs=120 imgsz=640 batch=16 iou=0.5
cos_lr=True                          # Menggunakan cosine annealing untuk learning rate
augment=True                        # Aktifkan augmentasi
hsv_h=0.01                          # Augmentasi warna (hue)
hsv_s=0.7                           # Augmentasi saturasi
hsv_v=0.4                           # Augmentasi nilai (brightness)
fliplr=0.5                          # Horizontal flip
mosaic=0.5                          # Mosaic augmentation
mixup=0.2                           # Mixup augmentation
close_mosaic=10                     # Nonaktifkan mosaic pada 10 epoch terakhir
val=True                            # Validasi selama training
plots=True
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 304MB/s]
# Ultralytics 8.3.151 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# prompt: i want to downoad the dir '/content/runs/detect/train/'

from google.colab import files
# %cd /content/runs/detect/train/
# !zip -r /content/train.zip *
files.download('/content/train.zip')
# Out:
# /content/runs/detect/train
#   adding: args.yaml (deflated 53%)
#   adding: confusion_matrix_normalized.png (deflated 25%)
#   adding: confusion_matrix.png (deflated 28%)
#   adding: F1_curve.png (deflated 9%)
#   adding: labels_correlogram.jpg (deflated 41%)
#   adding: labels.jpg (deflated 42%)
#   adding: P_curve.png (deflated 13%)
#   adding: PR_curve.png (deflated 17%)
#   adding: R_curve.png (deflated 10%)
#   adding: results.csv (deflated 62%)
#   adding: results.png (deflated 8%)
#   adding: train_batch0.jpg (deflated 8%)
#   adding: train_batch1.jpg (deflated 6%)
#   adding: train_batch2.jpg (deflated 7%)
#   adding: train_batch4400.jpg (deflated 15%)
#   adding: train_batch4401.jpg (deflated 15%)
#   adding: train_batch4402.jpg (deflated 15%)
#   adding: val_batch0_labels.jpg (deflated 14%)
#   adding: val_batch0_pred.jpg (deflated 14%)
#   adding: val_batch1_labels.jpg (deflated 17%)
#   adding: val_batch1_pred.jpg (deflated 17%)
# ...
